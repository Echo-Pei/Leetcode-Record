# %% [markdown]
# https://leetcode.com/problems/length-of-last-word/

# %%
class Solution:
    def lengthOfLastWord(self, s: str) -> int:
        s=s.split()
        if not s:
            return "0"
        else:
            return len(s[-1])

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-08a44fa71f66> in <module>
# ----> 1 s=s.split()
#       2 if not s:
#       3     return "0"
#       4 else:
#       5     return len(s[-1])
#
# NameError: name 's' is not defined
